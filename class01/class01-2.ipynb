# %% [markdown]
# #
# # Universidad EAFIT
# # 2026-2
# # Lab – Class 01 (Parte 2): Representación clásica del texto
#
# Este notebook complementa el trabajo práctico de la clase 01 del curso **Procesamiento de Lenguaje Natural Aplicado**. Aquí aplicaremos técnicas de representación vectorial y exploración de similitud entre documentos.
#
# ### En esta práctica:
# - Representación con Bag of Words y TF-IDF
# - Cálculo de similitud entre documentos
# - Reducción de dimensionalidad con PCA
# - Visualización de documentos

# %%
#configuración en google colab
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# dependencias que eventualmente requerirá instalar:
# !pip install nltk
# !pip install pandas
# !pip install matplotlib
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.4.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# cargar las librerias necesarias
## 1. nltk para 'procesamiento natural del lenguaje'
## 2. pandas para procesamiento de dataframes, muy usado en preparación de datos
## 3. re - expresiones regulares
## 4. numpy, codecs, etc - otras

# %%
# Librerías necesarias
import nltk
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.corpus import stopwords, reuters
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import PCA

# %%
# directorios (path) de entrada y salida:
#
path_in="gdrive/MyDrive/si7016-262/datasets/"
path_out="gdrive/MyDrive/si7016-262/out/"
#
## descomprimir el archivo: doaj_1.csv.zip
#
filename='doaj_1.csv'

# %%
# corpus de nltk para 'tokenizer' y 'stopwords'
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# abrir un archivo con pandas desde aws s3
#df = pd.read_csv('s3://si7016-262/doaj_1.csv',delimiter=',')
df = pd.read_csv(path_in+filename,delimiter=',')
df.head()
# Out:
#                                                title  \
# 0  Crystal structure of apatite type Ca2.49Nd7.51...
# 1  Genetic Programming for Medicinal Plant Family...
# 2  Managing reality shock: Expectations versus ex...
# 3  A Review of Systems and Technologies for Smart...
# 4  Functional testing of the vestibular ocular re...
#
#                                                  url                 path  \
# 0  http://scripts.iucr.org/cgi-bin/paper?S2056989...  article_batch_1.csv
# 1  http://journals.itb.ac.id/index.php/jictra/art...  article_batch_1.csv
# 2  https://sajip.co.za/index.php/sajip/article/vi...  article_batch_1.csv
# 3              http://www.mdpi.com/1996-1073/9/5/348  article_batch_1.csv
# 4  http://journal.frontiersin.org/Journal/10.3389...  article_batch_1.csv
#
#                                             keywords  category source  \
# 0  crystal structure, apatite structure type, cal...  articles   doaj
# 1                                                NaN  articles   doaj
# 2         Managing reality shock, Graduate engineers  articles   doaj
# 3  smart home, smart grid, energy management syst...  articles   doaj
# 4  Semicircular Canals, Dynamic Visual Acuity, He...  articles   doaj
#
#                                              content
# 0  The title compound, Ca2+xNd8–x(SiO4)6O2–0.5x (...
# 1  Information about medicinal plants that is ava...
# 2  The objective of the study is an analysis of t...
# 3  In the actual era of smart homes and smart gri...
# 4  The experimental assessment of the vestibulo-o...

# %%
df = df[['title','content']]
df.head()
# Out:
#                                                title  \
# 0  Crystal structure of apatite type Ca2.49Nd7.51...
# 1  Genetic Programming for Medicinal Plant Family...
# 2  Managing reality shock: Expectations versus ex...
# 3  A Review of Systems and Technologies for Smart...
# 4  Functional testing of the vestibular ocular re...
#
#                                              content
# 0  The title compound, Ca2+xNd8–x(SiO4)6O2–0.5x (...
# 1  Information about medicinal plants that is ava...
# 2  The objective of the study is an analysis of t...
# 3  In the actual era of smart homes and smart gri...
# 4  The experimental assessment of the vestibulo-o...

# %%
df['tokenized_title'] = df.apply(lambda row: nltk.word_tokenize(str(row['title'])), axis=1)
df['count_title'] = df.apply(lambda row: len(row['tokenized_title']), axis=1)
df['tokenized_content'] = df.apply(lambda row: nltk.word_tokenize(str(row['content'])), axis=1)
df['count_content'] = df.apply(lambda row: len(row['tokenized_content']), axis=1)

# %%
df.head()
# Out:
#                                                title  \
# 0  Crystal structure of apatite type Ca2.49Nd7.51...
# 1  Genetic Programming for Medicinal Plant Family...
# 2  Managing reality shock: Expectations versus ex...
# 3  A Review of Systems and Technologies for Smart...
# 4  Functional testing of the vestibular ocular re...
#
#                                              content  \
# 0  The title compound, Ca2+xNd8–x(SiO4)6O2–0.5x (...
# 1  Information about medicinal plants that is ava...
# 2  The objective of the study is an analysis of t...
# 3  In the actual era of smart homes and smart gri...
# 4  The experimental assessment of the vestibulo-o...
#
#                                      tokenized_title  count_title  \
# 0  [Crystal, structure, of, apatite, type, Ca2.49...           10
# 1  [Genetic, Programming, for, Medicinal, Plant, ...            8
# 2  [Managing, reality, shock, :, Expectations, ve...           10
# 3  [A, Review, of, Systems, and, Technologies, fo...           12
# 4  [Functional, testing, of, the, vestibular, ocu...           10
#
#                                    tokenized_content  count_content
# 0  [The, title, compound, ,, Ca2+xNd8–x, (, SiO4,...            141
# 1  [Information, about, medicinal, plants, that, ...            253
# 2  [The, objective, of, the, study, is, an, analy...            112
# 3  [In, the, actual, era, of, smart, homes, and, ...            134
# 4  [The, experimental, assessment, of, the, vesti...            204

# %%
# Tokenize todo el contenido de 'title'
all_tokens_title = []
for t in df['tokenized_title']:
    all_tokens_title.extend(t)

# %%
print("all_tokens_title =",len(all_tokens_title))
# Out:
# all_tokens_title = 820776

# %%
# analisis de frecuencia en palabras de 'title'
fdist_title = nltk.FreqDist(all_tokens_title)
print('Size BoW_title=',len(fdist_title))
topwordstitle = fdist_title.most_common(20)
# Out:
# Size BoW_title= 108032

# %%
x,y = zip(*topwordstitle)
plt.figure(figsize=(15,10))
plt.bar(x,y)
plt.xticks(rotation=90)
plt.show()

# %%
# analisis de frecuencia en palabras de 'content'
all_tokens_content = []
for t in df['tokenized_content']:
    all_tokens_content.extend(t)

# %%
print("all_tokens_content =",len(all_tokens_content))
# Out:
# all_tokens_content = 11458647

# %%
# analisis de frecuencia en palabras de 'content'
fdist_content = nltk.FreqDist(all_tokens_content)
print('Size BoW_content=',len(fdist_content))
topwordscontent = fdist_content.most_common(20)
# Out:
# Size BoW_content= 359295

# %%
x,y = zip(*topwordscontent)
plt.figure(figsize=(15,10))
plt.bar(x,y)
plt.xticks(rotation=90)
plt.show()

# %%
# stopwords en nltk
from nltk.corpus import stopwords

stop_words_nltk = set(stopwords.words('english'))
print(len(stop_words_nltk))
print(stop_words_nltk)
# Out:
# 198
# {"he'll", 'll', 'during', 'down', 'by', 'couldn', 'ourselves', 'the', 'didn', 'him', 'its', 'over', 'wasn', 'when', 'very', 'haven', 'so', 'isn', 'had', 're', 'how', 'and', "shan't", "it's", "you're", 'with', "should've", 'was', 'whom', 'am', "he's", 'more', 'but', "we've", 'at', 'y', 'ma', 'has', 'my', "needn't", 'mightn', 'if', 'shouldn', "they've", "we're", 'itself', 'myself', 'out', 'once', "haven't", 'own', 'be', 'should', 'too', 'yours', 'i', 'of', 'been', 'aren', 'than', 'who', 'against', 'most', 'this', "they'd", 'under', "hadn't", "you'll", 'any', 'does', 'about', 'needn', "we'd", 'won', "isn't", 'there', 'then', "i've", 'm', 'which', 'other', 'it', 'from', 'ours', 'they', "i'd", "won't", "that'll", "wouldn't", 'hasn', 'herself', 'mustn', 'we', 'both', 'no', 'same', 'ain', 'their', "weren't", "they'll", 'an', "mustn't", "you've", 'shan', 'again', 'doing', 'below', "doesn't", 'nor', 'up', 'will', 'in', 'hadn', 'or', 'before', "it'd", "hasn't", 'she', 'some', 'don', 'your', 'here', 'being', 'where', "i'll", 'theirs', 'do', 'just', "she's", 'each', "he'd", "don't", "aren't", 'were', "you'd", 'did', 'these', "i'm", "she'd", "shouldn't", 'further', 'because', 'into', 'that', 'them', 'above', 'through', 'her', 'd', "they're", 'himself', 'his', 'why', 'while', 'he', "it'll", 'have', 'having', 'hers', 'yourself', 'to', 'o', 't', 'yourselves', "didn't", "wasn't", 'what', 'as', 'for', 'now', 'such', 'can', 's', 'doesn', 'themselves', 'a', 'me', 'weren', 'only', 'on', "she'll", 'are', 'our', "mightn't", 'all', "couldn't", 'few', 'is', 'those', 've', 'wouldn', 'not', 'after', 'you', "we'll", 'between', 'off', 'until'}

# %%
# TOKENIZAR con nltk,
# ELIMINAR tokens de long = 1
# ELIMINAR caracteres que no sean alfanumericos
# REMOVER stop words
# graficar los 20 términos más frecuentes:

# ya tokenizado en all_tokens_title o all_tokens_content
tokens = [w.lower() for w in all_tokens_title if len(w)>1]
tokens = [re.sub(r'[^A-Za-z0-9]+','',w) for w in tokens]
tokens = [w for w in tokens if w not in stop_words_nltk]

fdist = nltk.FreqDist(tokens)
topwords = fdist.most_common(20)
print('Size of new BoW title =',len(fdist))
x,y = zip(*topwords)
plt.figure(figsize=(15,10))
plt.bar(x,y)
plt.xticks(rotation=90)
plt.show()
# Out:
# Size of new BoW title = 80375

# %%
# Stemming con NLTK

from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer

porter = PorterStemmer()
lancaster = LancasterStemmer()

#tokens = [porter.stem(w) for w in tokens]
tokens = [lancaster.stem(w) for w in tokens]

fdist = nltk.FreqDist(tokens)
topwords = fdist.most_common(20)
print('Size of new BoW title =',len(fdist))
x,y = zip(*topwords)
plt.figure(figsize=(15,10))
plt.bar(x,y)
plt.xticks(rotation=90)
plt.show()
# Out:
# Size of new BoW title = 61444

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# Lemmatization con NLTK

from nltk.stem import WordNetLemmatizer

wordnet_lemmatizer = WordNetLemmatizer()

#tokens = [wordnet_lemmatizer.lemmatize(w, pos="v") for w in tokens ]
tokens = [wordnet_lemmatizer.lemmatize(w) for w in tokens ]

fdist = nltk.FreqDist(tokens)
topwords = fdist.most_common(20)
print('Size of new BoW title =',len(fdist))
x,y = zip(*topwords)
plt.figure(figsize=(15,10))
plt.bar(x,y)
plt.xticks(rotation=90)
plt.show()
# Out:
# Size of new BoW title = 61168

# %%
# algunas funciones de mejoras para la tokenización:
tokens = [re.sub(r'[^A-Za-z0-9]+','',w) for w in all_tokens_content]
tokens = [w.lower() for w in tokens if len(w)>1]
tokens = [w for w in tokens if w.isalpha()]
fdist = nltk.FreqDist(tokens)
topwords = fdist.most_common(20)
print('Size of new BoW title =',len(fdist))
x,y = zip(*topwords)
plt.figure(figsize=(15,10))
plt.bar(x,y)
plt.xticks(rotation=90)
plt.show()
# Out:
# Size of new BoW title = 233772

# %% [markdown]
# # Reto corto – LAB 2
#
# ## Busca un corpus, puede ser de NLTK o kaggle, descargalo, y Construye dos representaciones del mismo corpus:
# - BoW unigram
# - TF-IDF bigram
#
# ## Responde:
#
# - ¿Cuál produce un vocabulario más grande?
# - ¿Cuál crees que funciona mejor para clasificación?
# - ¿Cuál para recuperación de información y por qué?
